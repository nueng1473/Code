# %%
from IPython.display import Image as im

# %%
Embed = im(
'http://blog.johnmuellerbooks.com/' + 'wp-content/uploads/2015/04/Layer-Hens.jpg')
Embed

# %%
ai = im(
'https://images.unsplash.com/' + 'photo-1505577058444-a3dab90d4253?ixlib=rb-1.2.1&auto=format&fit=crop&w=1534&q=80.jpg')
ai

# %%
z = im(
'https://images.unsplash.com/' +
'photo-1544457070-4cd773b4d71e?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1443&q=80.jpg')
z

# %%
a = im(
'https://st3.depositphotos.com/' + 
'1008648/19538/i/1600/depositphotos_195386246-stock-photo-white-robot-using-globe-network.jpg'
)
a

# %%
e = im(
'https://assets-global.website-files.com/' +
'5be0e3bae9b5e436ad47ab1c/5cae749690434cc712278f64_bigstock-122040128-e1541598347735.jpeg'
)
e
